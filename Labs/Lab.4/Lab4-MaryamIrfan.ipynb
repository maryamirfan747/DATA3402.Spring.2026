# %% [markdown]
# # Lab 4- Object Oriented Programming
#
# For all of the exercises below, make sure you provide tests of your solutions.

# %% [markdown]
# 1. Write a "counter" class that can be incremented up to a specified maximum value, will print an error if an attempt is made to increment beyond that value, and allows reseting the counter.

# %%
class counter:
    
    def __init__(self, max_value):
        self.max_value = max_value
        self.value = 0
    
    def increment(self):
        if self.value < self.max_value:
            self.value += 1
        else:
            print("Error: Counter has reached the maximum value.")
    
    def reset(self):
        self.value = 0
    
    def get_value(self):
        return self.value

# %%
c = counter(3)

c.increment()

# %%
c.increment()

# %%
c.increment()

# %%
c.increment()
# Out:
# Error: Counter has reached the maximum value.

# %%
print(c.get_value())
# Out:
# 3

# %%
c.reset()
print(c.get_value())
# Out:
# 0

# %% [markdown]
# 2. Copy and paste your solution to question 1 and modify it so that all the data held by the counter is private. Implement functions to check the value of the counter, check the maximum value, and check if the counter is at the maximum.

# %%
class Counter:
    
    def __init__(self, max_value):
        self.__max_value = max_value
        self.__value = 0
    
    def increment(self):
        if self.__value < self.__max_value:
            self.__value += 1
        else:
            print("Error: Counter has reached the maximum value.")
    
    def reset(self):
        self.__value = 0
    
    def get_value(self):
        return self.__value
    
    def get_max_value(self):
        return self.__max_value
    
    def is_at_max(self):
        return self.__value == self.__max_value
#Got some help from ChatGPT because I didn't understand the private part

# %%
c = Counter(3)

c.increment()

# %%
c.increment()
c.increment()

# %%
print(c.get_value())       
print(c.get_max_value())   
print(c.is_at_max())
# Out:
# 3
# 3
# True

# %%
c.reset()
print(c.get_value())
# Out:
# 0

# %% [markdown]
# 3. Implement a class to represent a rectangle, holding the length, width, and $x$ and $y$ coordinates of a corner of the object. Implement functions that compute the area and perimeter of the rectangle. Make all data members private and privide accessors to retrieve values of data members.

# %%
class Rectangle:
    
    def __init__(self, length, width, x, y):
        self.__length = length
        self.__width = width
        self.__x = x
        self.__y = y
    
    def area(self):
        return self.__length * self.__width
    
    def perimeter(self):
        return 2 * (self.__length + self.__width)
    
    def get_length(self):
        return self.__length
    
    def get_width(self):
        return self.__width
    
    def get_x(self):
        return self.__x
    
    def get_y(self):
        return self.__y

# %%
r = Rectangle(5, 3, 0, 0)

print(r.get_length())  
print(r.get_width())   
print(r.get_x())        
print(r.get_y())
# Out:
# 5
# 3
# 0
# 0

# %%
print(r.area())        
print(r.perimeter())
# Out:
# 15
# 16

# %% [markdown]
# 4. Implement a class to represent a circle, holding the radius and $x$ and $y$ coordinates of center of the object. Implement functions that compute the area and perimeter of the rectangle. Make all data members private and privide accessors to retrieve values of data members.

# %%
class Circle:
    
    def __init__(self, radius, x, y):
        self.__radius = radius
        self.__x = x
        self.__y = y
    
    def area(self):
        return 3.14 * self.__radius * self.__radius
    
    def perimeter(self):
        return 2 * 3.14 * self.__radius
    
    def get_radius(self):
        return self.__radius
    
    def get_x(self):
        return self.__x
    
    def get_y(self):
        return self.__y

# %%
c = Circle(4, 2, 3)

print(c.get_radius())   
print(c.get_x())        
print(c.get_y())
# Out:
# 4
# 2
# 3

# %%
print(c.area())         
print(c.perimeter())
# Out:
# 50.24
# 25.12

# %% [markdown]
# 5. Implement a common base class for the classes implemented in 3 and 4 above which implements all common methods as not implemented functions (virtual). Re-implement your regtangle and circule classes to inherit from the base class and overload the functions accordingly.

# %%
class Shape:
    
    def area(self):
        return
    
    def perimeter(self):
        return

# %%
class Rectangle(Shape):
    
    def __init__(self, length, width, x, y):
        self.__length = length
        self.__width = width
        self.__x = x
        self.__y = y
    
    def area(self):
        return self.__length * self.__width
    
    def perimeter(self):
        return 2 * (self.__length + self.__width)
    
    def get_length(self):
        return self.__length
    
    def get_width(self):
        return self.__width
    
    def get_x(self):
        return self.__x
    
    def get_y(self):
        return self.__y

# %%
class Circle(Shape):
    
    def __init__(self, radius, x, y):
        self.__radius = radius
        self.__x = x
        self.__y = y
    
    def area(self):
        return 3.14 * self.__radius * self.__radius
    
    def perimeter(self):
        return 2 * 3.14 * self.__radius
    
    def get_radius(self):
        return self.__radius
    
    def get_x(self):
        return self.__x
    
    def get_y(self):
        return self.__y

# %%
r = Rectangle(5, 3, 0, 0)
c = Circle(4, 2, 3)

print(r.area())   
print(c.area())
# Out:
# 15
# 50.24

# %% [markdown]
# 6. Implement a triangle class analogous to the rectangle and circle in question 5.

# %%
class Triangle(Shape):
    
    def __init__(self, a, b, c, x, y):
        self.__a = a
        self.__b = b
        self.__c = c
        self.__x = x
        self.__y = y
    
    def perimeter(self):
        return self.__a + self.__b + self.__c
    
    def area(self):
        s = (self.__a + self.__b + self.__c) / 2
        return (s * (s - self.__a) * (s - self.__b) * (s - self.__c)) ** 0.5
    
    def get_a(self):
        return self.__a
    
    def get_b(self):
        return self.__b
    
    def get_c(self):
        return self.__c
    
    def get_x(self):
        return self.__x
    
    def get_y(self):
        return self.__y

# %%
t = Triangle(3, 4, 5, 0, 0)

print(t.perimeter())
print(t.area())
# Out:
# 12
# 6.0

# %% [markdown]
# 7. Add a function to the object classes, including the base, that returns a list of up to 16 pairs of  $x$ and $y$ points on the parameter of the object.

# %%
class Shape:
    
    def area(self):
        return
    
    def perimeter(self):
        return
    
    def get_points(self):
        return []

# %%
class Rectangle(Shape):
    
    def __init__(self, length, width, x, y):
        self.__length = length
        self.__width = width
        self.__x = x
        self.__y = y
    
    def area(self):
        return self.__length * self.__width
    
    def perimeter(self):
        return 2 * (self.__length + self.__width)
    
    def get_points(self):
        x = self.__x
        y = self.__y
        l = self.__length
        w = self.__width
        
        return [
            (x, y),
            (x + l, y),
            (x + l, y + w),
            (x, y + w) ]

# %%
class Circle(Shape):
    
    def __init__(self, radius, x, y):
        self.__radius = radius
        self.__x = x
        self.__y = y
    
    def area(self):
        return 3.14 * self.__radius * self.__radius
    
    def perimeter(self):
        return 2 * 3.14 * self.__radius
    
    def get_points(self):
        r = self.__radius
        x = self.__x
        y = self.__y

        return [
            (x + r, y),
            (x - r, y),
            (x, y + r),
            (x, y - r),
            (x + r/2, y + r/2),
            (x - r/2, y + r/2),
            (x + r/2, y - r/2),
            (x - r/2, y - r/2)]

# %%
class Triangle(Shape):
    
    def __init__(self, a, b, c, x, y):
        self.__a = a
        self.__b = b
        self.__c = c
        self.__x = x
        self.__y = y
    
    def perimeter(self):
        return self.__a + self.__b + self.__c
    
    def area(self):
        s = (self.__a + self.__b + self.__c) / 2
        return (s * (s - self.__a) * (s - self.__b) * (s - self.__c)) ** 0.5
    
    def get_points(self):
        return [
            (self.__x, self.__y),
            (self.__x + self.__a, self.__y),
            (self.__x, self.__y + self.__b)]

# %%
r = Rectangle(4, 2, 0, 0)
print("Rectangle points:")
print(r.get_points())
print("Number of points:", len(r.get_points()))
print()
# Out:
# Rectangle points:
# [(0, 0), (4, 0), (4, 2), (0, 2)]
# Number of points: 4

# %%
c = Circle(3, 0, 0)
print("Circle points:")
print(c.get_points())
print("Number of points:", len(c.get_points()))
print()
# Out:
# Circle points:
# [(3, 0), (-3, 0), (0, 3), (0, -3), (1.5, 1.5), (-1.5, 1.5), (1.5, -1.5), (-1.5, -1.5)]
# Number of points: 8

# %%
t = Triangle(3, 4, 5, 0, 0)
print("Triangle points:")
print(t.get_points())
print("Number of points:", len(t.get_points()))
# Out:
# Triangle points:
# [(0, 0), (3, 0), (0, 4)]
# Number of points: 3

# %% [markdown]
# 8. Add a function to the object classes, including the base, that tests if a given set of $x$ and $y$ coordinates are inside of the object. You'll have to think through how to determine if a set of coordinates are inside an object for each object type.

# %%
class Shape:
    
    def area(self):
        return
    
    def perimeter(self):
        return
    
    def get_points(self):
        return []
    
    def contains(self, x, y):
        return

# %%
class Rectangle(Shape):
    
    def __init__(self, length, width, x, y):
        self.__length = length
        self.__width = width
        self.__x = x
        self.__y = y
    
    def area(self):
        return self.__length * self.__width
    
    def perimeter(self):
        return 2 * (self.__length + self.__width)
    
    def get_points(self):
        x = self.__x
        y = self.__y
        l = self.__length
        w = self.__width
        
        return [
            (x, y),
            (x + l, y),
            (x + l, y + w),
            (x, y + w) ]
    
    def contains(self, x, y):
        if self.__x <= x <= self.__x + self.__length and \
           self.__y <= y <= self.__y + self.__width:
            return True
        return False

# %%
class Circle(Shape):
    
    def __init__(self, radius, x, y):
        self.__radius = radius
        self.__x = x
        self.__y = y
    
    def area(self):
        return 3.14 * self.__radius * self.__radius
    
    def perimeter(self):
        return 2 * 3.14 * self.__radius
    
    def get_points(self):
        r = self.__radius
        x = self.__x
        y = self.__y

        return [
            (x + r, y),
            (x - r, y),
            (x, y + r),
            (x, y - r),
            (x + r/2, y + r/2),
            (x - r/2, y + r/2),
            (x + r/2, y - r/2),
            (x - r/2, y - r/2)]
        
    def contains(self, x, y):
        if abs(x - self.__x) <= self.__radius and \
           abs(y - self.__y) <= self.__radius:
            return True
        return False

# %%
class Triangle(Shape):
    
    def __init__(self, a, b, c, x, y):
        self.__a = a
        self.__b = b
        self.__c = c
        self.__x = x
        self.__y = y
    
    def perimeter(self):
        return self.__a + self.__b + self.__c
    
    def area(self):
        s = (self.__a + self.__b + self.__c) / 2
        return (s * (s - self.__a) * (s - self.__b) * (s - self.__c)) ** 0.5
    
    def get_points(self):
        return [
            (self.__x, self.__y),
            (self.__x + self.__a, self.__y),
            (self.__x, self.__y + self.__b)]
    
    def contains(self, x, y):
        if x < self.__x or y < self.__y:
            return False
        
        if x > self.__x + self.__base:
            return False
        
        if y > self.__y + self.__height:
            return False
        
        return True

# %%
r = Rectangle(4, 2, 0, 0)
print(r.contains(2, 1))  
print(r.contains(5, 1))
# Out:
# True
# False

# %%
c = Circle(3, 0, 0)
print(c.contains(1, 1))
print(c.contains(4, 0))
# Out:
# True
# False

# %%
t = Triangle(3, 4, 5, 2, 5)
print(t.contains(3, 3))
print(t.contains(6, 4))
# Out:
# False
# False

# %% [markdown]
# 9. Add a function in the base class of the object classes that returns true/false testing that the object overlaps with another object.

# %%
class Shape:
    
    def area(self):
        return
    
    def perimeter(self):
        return
    
    def get_points(self):
        return []
    
    def contains(self, x, y):
        return False
    
    def overlaps(self, other):
        
        for point in self.get_points():
            if other.contains(point[0], point[1]):
                return True
        
        for point in other.get_points():
            if self.contains(point[0], point[1]):
                return True
        
        return False

# %%
r1 = Rectangle(4, 4, 0, 0)
r2 = Rectangle(2, 2, 1, 1)

print(r1.overlaps(r2))
# Out:
# True

# %% [markdown]
# 10. Copy the `Canvas` class from lecture to in a python file creating a `paint` module. Copy your classes from above into the module and implement paint functions. Implement a `CompoundShape` class. Create a simple drawing demonstrating that all of your classes are working.

# %%
class Canvas:
    def __init__(self, width, height):
        self.width = width
        self.height = height
        # Empty canvas is a matrix with element being the "space" character
        self.data = [[' '] * width for i in range(height)]

    def set_pixel(self, row, col, char='*'):
        self.data[row][col] = char

    def get_pixel(self, row, col):
        return self.data[row][col]
    
    def clear_canvas(self):
        self.data = [[' '] * self.width for i in range(self.height)]
    
    def v_line(self, x, y, w, **kargs):
        for i in range(x,x+w):
            self.set_pixel(i,y, **kargs)

    def h_line(self, x, y, h, **kargs):
        for i in range(y,y+h):
            self.set_pixel(x,i, **kargs)
            
    def line(self, x1, y1, x2, y2, **kargs):
        slope = (y2-y1) / (x2-x1)
        for y in range(y1,y2):
            x= int(slope * y)
            self.set_pixel(x,y, **kargs)
            
    def display(self):
        print("\n".join(["".join(row) for row in self.data]))

# %%
class Shape:
    def area(self):
        return 0
    
    def perimeter(self):
        return 0
    
    def get_points(self):
        return []
    
    def contains(self, x, y):
        return False
    
    def overlaps(self, other):
        for px, py in self.get_points():
            if other.contains(px, py):
                return True
        for px, py in other.get_points():
            if self.contains(px, py):
                return True
        return False
    
    def paint(self, canvas, char='*'):
        for x, y in self.get_points():
            canvas.set_pixel(y, x, char)

# %%
class Rectangle(Shape):
    
    def __init__(self, length, width, x, y):
        self.length = length
        self.width = width
        self.x = x
        self.y = y
        
    def area(self):
        return self.__length * self.__width
    
    def perimeter(self):
        return 2 * (self.__length + self.__width)
    
    def get_points(self):
        points = []
        for i in range(self.width):
            for j in range(self.length):
                points.append((self.x + i, self.y + j))
        return points
    
    def contains(self, x, y):
        if self.__x <= x <= self.__x + self.__length and \
           self.__y <= y <= self.__y + self.__width:
            return True
        return False
    
#Used ChatGPT for this protion to help with the error I kept having

# %%
class Circle(Shape):
    
    def __init__(self, radius, x, y):
        self.__radius = radius
        self.__x = x
        self.__y = y
    
    def area(self):
        return 3.14 * self.__radius * self.__radius
    
    def perimeter(self):
        return 2 * 3.14 * self.__radius
    
    def get_points(self):
        points = []
        for dx in range(-self.__radius, self.__radius + 1):
            for dy in range(-self.__radius, self.__radius + 1):
                if dx*dx + dy*dy <= self.__radius*self.__radius:
                    points.append((self.__x + dx, self.__y + dy))
        return points
        
    def contains(self, x, y):
        if abs(x - self.__x) <= self.__radius and \
           abs(y - self.__y) <= self.__radius:
            return True
        return False

# %%
class Triangle(Shape):
    
    def __init__(self, a, b, c, x, y):
        self.__a = a
        self.__b = b
        self.__c = c
        self.__x = x
        self.__y = y
    
    def perimeter(self):
        return self.__a + self.__b + self.__c
    
    def area(self):
        s = (self.__a + self.__b + self.__c) / 2
        return (s * (s - self.__a) * (s - self.__b) * (s - self.__c)) ** 0.5
    
    def get_points(self):
        points = []
        for i in range(self.__a + 1):        
            for j in range(self.__b + 1):     
                if j <= (self.__b * i) // self.__a:
                    points.append((self.__x + i, self.__y + j))
        return points

    def contains(self, x, y):
        if x < self.__x or y < self.__y:
            return False
        
        if x > self.__x + self.__base:
            return False
        
        if y > self.__y + self.__height:
            return False
        
        return True

# %%
class CompoundShape(Shape):
    def __init__(self, *shapes):
        self.shapes = shapes

    def get_points(self):
        points = []
        for shape in self.shapes:
            points.extend(shape.get_points())
        return points

    def paint(self, canvas, char='*'):
        for shape in self.shapes:
            shape.paint(canvas, char)
            
#Used ChatGPT to fix the errors

# %%
c = Canvas(20, 10)

# %%
r = Rectangle(6, 4, 1, 1)
t = Triangle(4, 2, 5, 7, 7) 
ci = Circle(3, 15, 6)

# %%
r.paint(c, '#')
t.paint(c, '+')
ci.paint(c, 'o')

# %%
comp = CompoundShape(Rectangle(3, 2, 0, 7), 
                    Triangle(4, 2, 5, 7, 7))
comp.paint(c, '*')

# %%
c.display()
# Out:
#
#  ####
#  ####
#  ####          o
#  ####        ooooo
#  ####        ooooo
#  ####       ooooooo
# **     ***** ooooo
# **       *** ooooo
# **         *   o

# %% [markdown]
# 11. Create a `RasterDrawing` class. Demonstrate that you can create a drawing made of several shapes, paint the drawing, modify the drawing, and paint it again.

# %%
class RasterDrawing:
    def __init__(self, canvas):
        self.canvas = canvas
        self.shapes = []

    def add_shape(self, shape):
        self.shapes.append(shape)

    def remove_shape(self, shape):
        if shape in self.shapes:
            self.shapes.remove(shape)

    def paint(self):
        self.canvas.clear_canvas()
        for shape in self.shapes:
            shape.paint(self.canvas)
        self.canvas.display()

# %%
c = Canvas(20, 10)

# %%
r = Rectangle(6, 4, 1, 1)
t = Triangle(4, 2, 5, 7, 7)
ci = Circle(3, 15, 6)
r2 = Rectangle(3, 2, 0, 7)

# %%
drawing = RasterDrawing(c)

# %%
drawing.add_shape(r)
drawing.add_shape(t)
drawing.add_shape(ci)

# %%
drawing.paint()
# Out:
#
#  ****
#  ****
#  ****          *
#  ****        *****
#  ****        *****
#  ****       *******
#        ***** *****
#          *** *****
#            *   *

# %%
drawing.remove_shape(t)
drawing.add_shape(r2)

# %%
drawing.paint()
# Out:
#
#  ****
#  ****
#  ****          *
#  ****        *****
#  ****        *****
#  ****       *******
# **           *****
# **           *****
# **             *

# %% [markdown]
# 12. Implement the ability to load/save raster drawings and demonstate that your method works. One way to implement this ability:
#
#    * Overload `__repr__` functions of all objects to return strings of the python code that would construct the object.
#
#    * In the save method of raster drawing class, store the representations into the file.
#    * Write a loader function that reads the file and uses `eval` to instantiate the object.
#
# For example:

# %%
class foo:
    def __init__(self,a,b=None):
        self.a=a
        self.b=b
        
    def __repr__(self):
        return "foo("+repr(self.a)+","+repr(self.b)+")"
    
    def save(self,filename):
        f=open(filename,"w")
        f.write(self.__repr__())
        f.close()
        
   
def foo_loader(filename):
    f=open(filename,"r")
    tmp=eval(f.read())
    f.close()
    return tmp

# %%
# Test
print(repr(foo(1,"hello")))
# Out:
# foo(1,'hello')

# %%
# Create an object and save it
ff=foo(1,"hello")
ff.save("Test.foo")

# %%
# Check contents of the saved file
# !cat Test.foo
# Out:
# foo(1,'hello')

# %%
# Load the object
ff_reloaded=foo_loader("Test.foo")
ff_reloaded
# Out:
# foo(1,'hello')

# %%
class Rectangle(Shape):
    
    def __init__(self, length, width, x, y):
        self.length = length
        self.width = width
        self.x = x
        self.y = y
        
    def area(self):
        return self.__length * self.__width
    
    def perimeter(self):
        return 2 * (self.__length + self.__width)
    
    def get_points(self):
        points = []
        for i in range(self.width):
            for j in range(self.length):
                points.append((self.x + i, self.y + j))
        return points
    
    def contains(self, x, y):
        if self.__x <= x <= self.__x + self.__length and \
           self.__y <= y <= self.__y + self.__width:
            return True
        return False
    
    def __repr__(self):
        return f"Rectangle({self.width},{self.length},{self.x},{self.y})"

# %%
class Circle(Shape):
    
    def __init__(self, radius, x, y):
        self.__radius = radius
        self.__x = x
        self.__y = y
    
    def area(self):
        return 3.14 * self.__radius * self.__radius
    
    def perimeter(self):
        return 2 * 3.14 * self.__radius
    
    def get_points(self):
        points = []
        for dx in range(-self.__radius, self.__radius + 1):
            for dy in range(-self.__radius, self.__radius + 1):
                if dx*dx + dy*dy <= self.__radius*self.__radius:
                    points.append((self.__x + dx, self.__y + dy))
        return points
        
    def contains(self, x, y):
        if abs(x - self.__x) <= self.__radius and \
           abs(y - self.__y) <= self.__radius:
            return True
        return False
    
    def __repr__(self):
        return f"Circle({self.__radius},{self.__x},{self.__y})"

# %%
class Triangle(Shape):
    
    def __init__(self, a, b, c, x, y):
        self.__a = a
        self.__b = b
        self.__c = c
        self.__x = x
        self.__y = y
    
    def perimeter(self):
        return self.__a + self.__b + self.__c
    
    def area(self):
        s = (self.__a + self.__b + self.__c) / 2
        return (s * (s - self.__a) * (s - self.__b) * (s - self.__c)) ** 0.5
    
    def get_points(self):
        points = []
        for i in range(self.__a + 1):        
            for j in range(self.__b + 1):     
                if j <= (self.__b * i) // self.__a:
                    points.append((self.__x + i, self.__y + j))
        return points

    def contains(self, x, y):
        if x < self.__x or y < self.__y:
            return False
        
        if x > self.__x + self.__base:
            return False
        
        if y > self.__y + self.__height:
            return False
        
        return True
    
    def __repr__(self):
        return f"Triangle({self.__a},{self.__b},{self.__c},{self.__x},{self.__y})"

# %%
class RasterDrawing:
    def __init__(self, canvas):
        self.canvas = canvas
        self.shapes = []

    def add_shape(self, shape):
        self.shapes.append(shape)

    def remove_shape(self, shape):
        if shape in self.shapes:
            self.shapes.remove(shape)

    def paint(self):
        self.canvas.clear_canvas()
        for shape in self.shapes:
            shape.paint(self.canvas)
        self.canvas.display()

    def save(self, filename):
        f = open(filename, "w")
        for shape in self.shapes:
            f.write(repr(shape) + "\n")
        f.close()

# %%
def load_raster_drawing(filename, canvas):
    f = open(filename, "r")
    drawing = RasterDrawing(canvas)
    for line in f:
        line = line.strip()
        if line:
            shape = eval(line)
            drawing.add_shape(shape)
    f.close()
    return drawing

# %%
c = Canvas(20, 10)

# %%
drawing = RasterDrawing(c)
drawing.add_shape(Rectangle(6, 4, 1, 1))
drawing.add_shape(Triangle(4, 2, 5, 7, 7))
drawing.add_shape(Circle(3, 15, 6))

# %%
drawing.paint()
# Out:
#
#  ****
#  ****
#  ****          *
#  ****        *****
#  ****        *****
#  ****       *******
#        ***** *****
#          *** *****
#            *   *

# %%
drawing.save("my_drawing.txt")

# %%
c2 = Canvas(20, 10)

# %%
loaded_drawing = load_raster_drawing("my_drawing.txt", c2)

# %%
loaded_drawing.paint()
# Out:
#
#  ******
#  ******
#  ******        *
#  ******      *****
#              *****
#             *******
#        ***** *****
#          *** *****
#            *   *
